# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from scipy.stats import shapiro
import time
from river import drift

# %%
df = pd.read_csv('edge_bindrag.csv')

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
# Filter the dataset to include only the columns in the 'feat' list
X = df.drop(['Attack_label'],axis=1) # Assuming 'feat' is a list of column names
y = df['Attack_label']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.5, test_size=0.5, shuffle=True, random_state=0
)

# %%
# Import the online learning metrics and algorithms from the River library
from river import metrics
from river import stream
from river import tree,neighbors,naive_bayes,ensemble,linear_model,forest
from river.drift.binary import DDM, EDDM,HDDM_A,HDDM_W
import logging

# %%
def setup_logger(log_file="adaptive_learning.log"):
    """
    Set up a logger that writes only to a file.
    """
    logger = logging.getLogger("AdaptiveLearningLogger")
    logger.setLevel(logging.INFO)

    # Check if handlers are already added to avoid duplicates
    if not logger.hasHandlers():
        # Create a file handler
        file_handler = logging.FileHandler(log_file)
        file_handler.setLevel(logging.INFO)

        # Create a logging format
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(formatter)

        # Add the handler to the logger
        logger.addHandler(file_handler)

    return logger

def adaptive_learning(model, X_train, y_train, X_test, y_test, logger=None):
    metric = metrics.Accuracy() # Use accuracy as the metric
    i = 0 # count the number of evaluated data points
    t = [] # record the number of evaluated data points
    m = [] # record the real-time accuracy
    yt = [] # record all the true Attack_types of the test set
    yp = [] # record all the predicted Attack_types of the test set
    
    eddm = drift.binary.EDDM()
    
    # Learn the training set
    for xi1, yi1 in zip(X_train.values, y_train): 
        xi = dict(zip(X_train.columns, xi1))   
        model.learn_one(xi, yi1) 

    # Predict the test set and perform drift detection
    for x_val, y_val in zip(X_test.values, y_test):
        x = dict(zip(X_test.columns, x_val))
        y_pred = model.predict_one(x)  # Predict the test sample
        model.learn_one(x, y_val) # Learn the test sample
        metric.update(y_val, y_pred) # Update the real-time accuracy
        
        # Drift detection part
        val = 0
        
        if y_val != y_pred:
           val = 1 
           eddm.update(y_val)
        if eddm.drift_detected:
            logger.info(f"Change detected at index {i}, input value: {y_val}")
        if eddm.warning_detected:
           logger.warning(f"Warning detected at index {i}")


        # Performance evaluation
        t.append(i)
        m.append(metric.get() * 100)
        yt.append(y_val)
        yp.append(y_pred)
        i += 1

    print("Accuracy: " + str(round(accuracy_score(yt, yp), 4) * 100) + "%")
    print("Precision: " + str(round(precision_score(yt, yp,average='weighted'), 4) * 100) + "%")
    print("Recall: " + str(round(recall_score(yt, yp,average='weighted'), 4) * 100) + "%")
    print("F1-score: " + str(round(f1_score(yt, yp,average='weighted'), 4) * 100) + "%")

    return t, m, logger

# %%
from river.drift.binary import DDM, EDDM,HDDM_A,HDDM_W

# %%
#With drift of 80

def adaptive_learning(model, X_train, y_train, X_test, y_test):
    metric = metrics.Accuracy() # Use accuracy as the metric
    i = 0 # count the number of evaluated data points
    t = [] # record the number of evaluated data points
    m = [] # record the real-time accuracy
    yt = [] # record all the true labels of the test set
    yp = [] # record all the predicted labels of the test set
    
    eddm = drift.binary.EDDM()
    
    # Learn the training set
    for xi1, yi1 in zip(X_train.values, y_train): 
        xi = dict(zip(X_train.columns, xi1))   
        model.learn_one(xi, yi1) 

    # Predict the test set and perform drift detection
    for x_val, y_val in zip(X_test.values, y_test):
        x = dict(zip(X_test.columns, x_val))
        y_pred = model.predict_one(x)  # Predict the test sample
        model.learn_one(x, y_val) # Learn the test sample
        metric.update(y_val, y_pred) # Update the real-time accuracy
        
        # Drift detection part
        val = 0
        
        if y_val != y_pred:
           val = 1 
           eddm.update(y_val)
        if eddm.drift_detected:
            print(f"Change detected at index {i}, input value: {y_val}")
            
           
        if eddm.warning_detected:
           print(f"Warning detected at index {i}")
        # Print samples every 80 iterations
        if i % 80 == 0:
            print(f"Sample {i}: True label: {y_val}, Predicted label: {y_pred}") 

        # Performance evaluation
        t.append(i)
        m.append(metric.get() * 100)
        yt.append(y_val)
        yp.append(y_pred)
        i += 1

    print("Accuracy: " + str(round(accuracy_score(yt, yp), 4) * 100) + "%")
    print("Precision: " + str(round(precision_score(yt, yp), 4) * 100) + "%")
    print("Recall: " + str(round(recall_score(yt, yp), 4) * 100) + "%")
    print("F1-score: " + str(round(f1_score(yt, yp), 4) * 100) + "%")

    return t, m

# %%
# Define a figure function that shows the real-time accuracy changes
def acc_fig(t, m, name):
    plt.rcParams.update({'font.size': 15})
    plt.figure(1,figsize=(10,6)) 
    sns.set_style("darkgrid")
    plt.clf() 
    #if m:  # Check if m is not empty
    plt.plot(t, m, '-b', label='Avg Accuracy: %.2f%%' % (m[-1]))

    #plt.plot(t,m,'-b',label='Avg Accuracy: %.2f%%'%(m[-1]))

    plt.legend(loc='best')
    plt.title(name+' on IoTID20 dataset', fontsize=15)
    plt.xlabel('Number of samples')
    plt.ylabel('Accuracy (%)')

    plt.draw()

# %%
# %%time
# Use the Adaptive Random Forest (ARF) model with ADWIN drift detector as a baseline model
name = "ARF model"
model = forest.ARFClassifier(n_models = 3) # Define the model
logger = setup_logger("drift_detection.log")
t, m, logger = adaptive_learning(model, X_train, y_train, X_test, y_test, logger=logger) # Learn the model on the dataset
acc_fig(t, m, name) # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:5
#
# TypeError: adaptive_learning() got an unexpected keyword argument 'logger'

# %%
# %%time
# Use the Adaptive Random Forest (ARF) model with ADWIN drift detector as a baseline model
name = "ARF model"
model = forest.ARFClassifier(n_models = 3,drift_detector=EDDM()) # Define the model
t, m = adaptive_learning(model, X_train, y_train, X_test, y_test) # Learn the model on the dataset
acc_fig(t, m, name) # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# Sample 0: True label: 1.0, Predicted label: 1.0
# Sample 80: True label: 0.0, Predicted label: 1.0
# Sample 160: True label: 1.0, Predicted label: 1.0
# Sample 240: True label: 1.0, Predicted label: 1.0
# Sample 320: True label: 1.0, Predicted label: 1.0
# Sample 400: True label: 1.0, Predicted label: 1.0
# Sample 480: True label: 1.0, Predicted label: 1.0
# Sample 560: True label: 1.0, Predicted label: 1.0
# Sample 640: True label: 1.0, Predicted label: 1.0
# Sample 720: True label: 0.0, Predicted label: 1.0
# Sample 800: True label: 0.0, Predicted label: 0.0
# Sample 880: True label: 1.0, Predicted label: 1.0
# Sample 960: True label: 0.0, Predicted label: 1.0
# Sample 1040: True label: 1.0, Predicted label: 1.0
# Sample 1120: True label: 1.0, Predicted label: 1.0
# Sample 1200: True label: 1.0, Predicted label: 1.0
# Sample 1280: True label: 1.0, Predicted label: 1.0
# Sample 1360: True label: 1.0, Predicted label: 1.0
# Sample 1440: True label: 1.0, Predicted label: 1.0
# Sample 1520: True label: 1.0, Predicted label: 1.0
# Sample 1600: True label: 0.0, Predicted label: 0.0
# Sample 1680: True label: 1.0, Predicted label: 1.0
# Sample 1760: True label: 1.0, Predicted label: 1.0
# Sample 1840: True label: 1.0, Predicted label: 1.0
# Sample 1920: True label: 1.0, Predicted label: 1.0
# Sample 2000: True label: 1.0, Predicted label: 1.0
# Sample 2080: True label: 1.0, Predicted label: 1.0
# Sample 2160: True label: 1.0, Predicted label: 1.0
# Sample 2240: True label: 1.0, Predicted label: 1.0
# Sample 2320: True label: 1.0, Predicted label: 1.0
# Sample 2400: True label: 1.0, Predicted label: 1.0
# Sample 2480: True label: 0.0, Predicted label: 1.0
# Sample 2560: True label: 1.0, Predicted label: 1.0
# Sample 2640: True label: 1.0, Predicted label: 1.0
# Sample 2720: True label: 1.0, Predicted label: 1.0
# Sample 2800: True label: 1.0, Predicted label: 1.0
# Sample 2880: True label: 1.0, Predicted label: 1.0
# Sample 2960: True label: 1.0, Predicted label: 1.0
# Sample 3040: True label: 1.0, Predicted label: 1.0
# Sample 3120: True label: 1.0, Predicted label: 1.0
# Sample 3200: True label: 1.0, Predicted label: 1.0
# Sample 3280: True label: 0.0, Predicted label: 0.0
# Sample 3360: True label: 1.0, Predicted label: 1.0
# Sample 3440: True label: 0.0, Predicted label: 1.0
# Sample 3520: True label: 1.0, Predicted label: 1.0
# Sample 3600: True label: 1.0, Predicted label: 1.0
# Sample 3680: True label: 0.0, Predicted label: 0.0
# Sample 3760: True label: 1.0, Predicted label: 1.0
# Sample 3840: True label: 0.0, Predicted label: 1.0
# Sample 3920: True label: 1.0, Predicted label: 1.0
# Sample 4000: True label: 1.0, Predicted label: 1.0
# Sample 4080: True label: 1.0, Predicted label: 1.0
# Sample 4160: True label: 1.0, Predicted label: 1.0
# Sample 4240: True label: 1.0, Predicted label: 1.0
# Sample 4320: True label: 1.0, Predicted label: 1.0
# Sample 4400: True label: 0.0, Predicted label: 0.0
# Sample 4480: True label: 1.0, Predicted label: 1.0
# Sample 4560: True label: 1.0, Predicted label: 1.0
# Sample 4640: True label: 1.0, Predicted label: 1.0
# Sample 4720: True label: 1.0, Predicted label: 1.0
# Sample 4800: True label: 1.0, Predicted label: 1.0
# Sample 4880: True label: 1.0, Predicted label: 1.0
# Sample 4960: True label: 1.0, Predicted label: 1.0
# Sample 5040: True label: 1.0, Predicted label: 1.0
# Sample 5120: True label: 1.0, Predicted label: 1.0
# Sample 5200: True label: 1.0, Predicted label: 1.0
# Sample 5280: True label: 1.0, Predicted label: 1.0
# Sample 5360: True label: 1.0, Predicted label: 1.0
# Sample 5440: True label: 1.0, Predicted label: 1.0
# Sample 5520: True label: 1.0, Predicted label: 1.0
# Sample 5600: True label: 1.0, Predicted label: 1.0
# Sample 5680: True label: 1.0, Predicted label: 1.0
# Sample 5760: True label: 1.0, Predicted label: 1.0
# Sample 5840: True label: 1.0, Predicted label: 1.0
# Sample 5920: True label: 0.0, Predicted label: 1.0
# Sample 6000: True label: 1.0, Predicted label: 1.0
# Sample 6080: True label: 1.0, Predicted label: 1.0
# Sample 6160: True label: 1.0, Predicted label: 1.0
# Sample 6240: True label: 1.0, Predicted label: 1.0
# Sample 6320: True label: 1.0, Predicted label: 1.0
# Sample 6400: True label: 1.0, Predicted label: 1.0
# Sample 6480: True label: 1.0, Predicted label: 1.0
# Sample 6560: True label: 0.0, Predicted label: 0.0
# Sample 6640: True label: 1.0, Predicted label: 1.0
# Sample 6720: True label: 0.0, Predicted label: 1.0
# Sample 6800: True label: 1.0, Predicted label: 1.0
# Sample 6880: True label: 1.0, Predicted label: 1.0
# Sample 6960: True label: 0.0, Predicted label: 1.0
# Sample 7040: True label: 1.0, Predicted label: 1.0
# Sample 7120: True label: 1.0, Predicted label: 1.0
# Sample 7200: True label: 1.0, Predicted label: 1.0
# Sample 7280: True label: 1.0, Predicted label: 1.0
# Sample 7360: True label: 1.0, Predicted label: 1.0
# Sample 7440: True label: 1.0, Predicted label: 1.0
# Sample 7520: True label: 0.0, Predicted label: 0.0
# Sample 7600: True label: 1.0, Predicted label: 1.0
# Sample 7680: True label: 1.0, Predicted label: 1.0
# Sample 7760: True label: 1.0, Predicted label: 1.0
# Sample 7840: True label: 1.0, Predicted label: 1.0
# Sample 7920: True label: 1.0, Predicted label: 1.0
# Sample 8000: True label: 1.0, Predicted label: 1.0
# Sample 8080: True label: 1.0, Predicted label: 1.0
# Sample 8160: True label: 1.0, Predicted label: 1.0
# Sample 8240: True label: 1.0, Predicted label: 1.0
# Sample 8320: True label: 1.0, Predicted label: 1.0
# Sample 8400: True label: 1.0, Predicted label: 1.0
# Sample 8480: True label: 1.0, Predicted label: 1.0
# Sample 8560: True label: 0.0, Predicted label: 0.0
# Sample 8640: True label: 1.0, Predicted label: 1.0
# Sample 8720: True label: 1.0, Predicted label: 1.0
# Sample 8800: True label: 1.0, Predicted label: 1.0
# Sample 8880: True label: 1.0, Predicted label: 1.0
# Sample 8960: True label: 1.0, Predicted label: 1.0
# Sample 9040: True label: 1.0, Predicted label: 1.0
# Sample 9120: True label: 1.0, Predicted label: 1.0
# Sample 9200: True label: 1.0, Predicted label: 1.0
# Sample 9280: True label: 1.0, Predicted label: 1.0
# Sample 9360: True label: 1.0, Predicted label: 1.0
# Sample 9440: True label: 1.0, Predicted label: 1.0
# Sample 9520: True label: 1.0, Predicted label: 1.0
# Sample 9600: True label: 1.0, Predicted label: 1.0
# Sample 9680: True label: 0.0, Predicted label: 1.0
# Sample 9760: True label: 1.0, Predicted label: 1.0
# Sample 9840: True label: 1.0, Predicted label: 1.0
# Sample 9920: True label: 1.0, Predicted label: 1.0
# Sample 10000: True label: 1.0, Predicted label: 1.0
# Sample 10080: True label: 1.0, Predicted label: 1.0
# Sample 10160: True label: 1.0, Predicted label: 1.0
# Sample 10240: True label: 1.0, Predicted label: 1.0
# Sample 10320: True label: 1.0, Predicted label: 1.0
# Sample 10400: True label: 1.0, Predicted label: 1.0
# Sample 10480: True label: 1.0, Predicted label: 1.0
# Sample 10560: True label: 1.0, Predicted label: 1.0
# Sample 10640: True label: 0.0, Predicted label: 1.0
# Sample 10720: True label: 1.0, Predicted label: 1.0
# Sample 10800: True label: 1.0, Predicted label: 1.0
# Sample 10880: True label: 1.0, Predicted label: 1.0
# Sample 10960: True label: 1.0, Predicted label: 1.0
# Sample 11040: True label: 1.0, Predicted label: 1.0
# Sample 11120: True label: 1.0, Predicted label: 1.0
# Sample 11200: True label: 1.0, Predicted label: 1.0
# Sample 11280: True label: 0.0, Predicted label: 0.0
# Sample 11360: True label: 1.0, Predicted label: 1.0
# Sample 11440: True label: 1.0, Predicted label: 1.0
# Sample 11520: True label: 1.0, Predicted label: 1.0
# Warning detected at index 11562
# Warning detected at index 11563
# Warning detected at index 11564
# Warning detected at index 11565
# Warning detected at index 11566
# Warning detected at index 11567
# Warning detected at index 11568
# Warning detected at index 11569
# Warning detected at index 11570
# Warning detected at index 11571
# Warning detected at index 11572
# Warning detected at index 11573
# Warning detected at index 11574
# Warning detected at index 11575
# Warning detected at index 11576
# Warning detected at index 11577
# Warning detected at index 11578
# Warning detected at index 11579
# Warning detected at index 11580
# Warning detected at index 11581
# Warning detected at index 11582
# Warning detected at index 11583
# Warning detected at index 11584
# Warning detected at index 11585
# Warning detected at index 11586
# Warning detected at index 11587
# Warning detected at index 11588
# Warning detected at index 11589
# Warning detected at index 11590
# Warning detected at index 11591
# Warning detected at index 11592
# Warning detected at index 11593
# Warning detected at index 11594
# Warning detected at index 11595
# Warning detected at index 11596
# Warning detected at index 11597
# Warning detected at index 11598
# Warning detected at index 11599
# Warning detected at index 11600
# Sample 11600: True label: 1.0, Predicted label: 1.0
# Warning detected at index 11601
# Warning detected at index 11602
# Warning detected at index 11603
# Warning detected at index 11604
# Warning detected at index 11605
# Warning detected at index 11606
# Warning detected at index 11607
# Warning detected at index 11608
# Warning detected at index 11609
# Warning detected at index 11610
# Warning detected at index 11611
# Warning detected at index 11612
# Warning detected at index 11613
# Warning detected at index 11614
# Warning detected at index 11615
# Warning detected at index 11616
# Warning detected at index 11617
# Warning detected at index 11618
# Warning detected at index 11619
# Warning detected at index 11620
# Warning detected at index 11621
# Warning detected at index 11622
# Warning detected at index 11623
# Warning detected at index 11624
# Warning detected at index 11625
# Warning detected at index 11626
# Warning detected at index 11627
# Warning detected at index 11628
# Warning detected at index 11629
# Warning detected at index 11630
# Warning detected at index 11631
# Warning detected at index 11632
# Warning detected at index 11633
# Warning detected at index 11634
# Warning detected at index 11635
# Warning detected at index 11636
# Warning detected at index 11637
# Warning detected at index 11638
# Warning detected at index 11639
# Warning detected at index 11640
# Warning detected at index 11641
# Warning detected at index 11642
# Warning detected at index 11643
# Warning detected at index 11644
# Warning detected at index 11645
# Warning detected at index 11646
# Warning detected at index 64863
# Warning detected at index 64864
# Warning detected at index 64865
# Warning detected at index 64866
# Warning detected at index 64867
# Warning detected at index 64868
# Warning detected at index 64869
# Warning detected at index 64870
# Warning detected at index 64871
# Warning detected at index 64872
# Warning detected at index 64873
# Warning detected at index 64874
# Warning detected at index 64875
# Warning detected at index 64876
# Warning detected at index 64877
# Warning detected at index 64878
# Warning detected at index 64879
# Warning detected at index 64880
# Sample 64880: True label: 1.0, Predicted label: 1.0
# Warning detected at index 64881
# Warning detected at index 64882
# Warning detected at index 64883
# Warning detected at index 64884
# Warning detected at index 64885
# Warning detected at index 64886
# Warning detected at index 64887
# Warning detected at index 64888
# Warning detected at index 64889
# Warning detected at index 64890
# Warning detected at index 64891
# Warning detected at index 64892
# Warning detected at index 64893
# Warning detected at index 64894
# Warning detected at index 64895
# Warning detected at index 64896
# Warning detected at index 64897
# Warning detected at index 64898
# Warning detected at index 64899
# Warning detected at index 64900
# Warning detected at index 64901
# Warning detected at index 64902
# Warning detected at index 64903
# Warning detected at index 64904
# Warning detected at index 64905
# Warning detected at index 64906
# Warning detected at index 64907
# Warning detected at index 64908
# Warning detected at index 64909
# Warning detected at index 64910
# Warning detected at index 64911
# Warning detected at index 64912
# Warning detected at index 64913
# Warning detected at index 64914
# Warning detected at index 64915
# Warning detected at index 64916
# Warning detected at index 64917
# Warning detected at index 64918
# Warning detected at index 64919
# Warning detected at index 64920
# Warning detected at index 64921
# Warning detected at index 64922
# Warning detected at index 64923
# Warning detected at index 64924
# Warning detected at index 64925
# Warning detected at index 64926
# Warning detected at index 64927
# Warning detected at index 64928
# Warning detected at index 64929
# Warning detected at index 64930
# Warning detected at index 64931
# Warning detected at index 64932
# Warning detected at index 64933
# Change detected at index 64934, input value: 1.0
# Warning detected at index 64934
# Change detected at index 64935, input value: 1.0
# Warning detected at index 64935
# Change detected at index 64936, input value: 1.0
# Warning detected at index 64936
# Change detected at index 64937, input value: 1.0
# Warning detected at index 64937
# Change detected at index 64938, input value: 1.0
# Warning detected at index 64938
# Change detected at index 64939, input value: 0.0
# Warning detected at index 64939
# Change detected at index 64940, input value: 1.0
# Warning detected at index 64940
# Change detected at index 64941, input value: 1.0
# Warning detected at index 64941
# Change detected at index 64942, input value: 1.0
# Warning detected at index 64942
# Sample 64960: True label: 1.0, Predicted label: 1.0
# Sample 65040: True label: 1.0, Predicted label: 1.0
# Sample 65120: True label: 1.0, Predicted label: 1.0
# Sample 65200: True label: 1.0, Predicted label: 1.0
# Sample 65280: True label: 1.0, Predicted label: 1.0
# Sample 65360: True label: 1.0, Predicted label: 1.0
# Sample 65440: True label: 1.0, Predicted label: 1.0
# Sample 65520: True label: 0.0, Predicted label: 0.0
# Sample 65600: True label: 1.0, Predicted label: 1.0
# Sample 65680: True label: 1.0, Predicted label: 1.0
# Sample 65760: True label: 1.0, Predicted label: 1.0
# Sample 65840: True label: 1.0, Predicted label: 1.0
# Sample 65920: True label: 1.0, Predicted label: 1.0
# Sample 66000: True label: 1.0, Predicted label: 1.0
# Sample 66080: True label: 1.0, Predicted label: 1.0
# Sample 66160: True label: 1.0, Predicted label: 1.0
# Sample 66240: True label: 1.0, Predicted label: 1.0
# Sample 66320: True label: 1.0, Predicted label: 1.0
# Sample 66400: True label: 1.0, Predicted label: 1.0
# Sample 66480: True label: 1.0, Predicted label: 1.0
# Sample 66560: True label: 1.0, Predicted label: 1.0
# Sample 66640: True label: 1.0, Predicted label: 1.0
# Sample 66720: True label: 1.0, Predicted label: 1.0
# Sample 66800: True label: 1.0, Predicted label: 1.0
# Sample 66880: True label: 1.0, Predicted label: 1.0
# Sample 66960: True label: 1.0, Predicted label: 1.0
# Sample 67040: True label: 1.0, Predicted label: 1.0
# Sample 67120: True label: 0.0, Predicted label: 1.0
# Sample 67200: True label: 1.0, Predicted label: 1.0
# Sample 67280: True label: 1.0, Predicted label: 1.0
# Sample 67360: True label: 1.0, Predicted label: 1.0
# Sample 67440: True label: 1.0, Predicted label: 1.0
# Sample 67520: True label: 1.0, Predicted label: 1.0
# Sample 67600: True label: 1.0, Predicted label: 1.0
# Sample 67680: True label: 1.0, Predicted label: 1.0
# Sample 67760: True label: 1.0, Predicted label: 1.0
# Sample 67840: True label: 1.0, Predicted label: 1.0
# Sample 67920: True label: 1.0, Predicted label: 1.0
# Sample 68000: True label: 1.0, Predicted label: 1.0
# Sample 68080: True label: 1.0, Predicted label: 1.0
# Sample 68160: True label: 1.0, Predicted label: 1.0
# Sample 68240: True label: 1.0, Predicted label: 1.0
# Sample 68320: True label: 1.0, Predicted label: 1.0
# Sample 68400: True label: 0.0, Predicted label: 0.0
# Sample 68480: True label: 1.0, Predicted label: 1.0
# Sample 68560: True label: 0.0, Predicted label: 0.0
# Sample 68640: True label: 1.0, Predicted label: 1.0
# Sample 68720: True label: 1.0, Predicted label: 1.0
# Sample 68800: True label: 1.0, Predicted label: 1.0
# Sample 68880: True label: 1.0, Predicted label: 1.0
# Sample 68960: True label: 0.0, Predicted label: 0.0
# Sample 69040: True label: 1.0, Predicted label: 1.0
# Sample 69120: True label: 0.0, Predicted label: 1.0
# Sample 69200: True label: 1.0, Predicted label: 1.0
# Sample 69280: True label: 1.0, Predicted label: 1.0
# Sample 69360: True label: 1.0, Predicted label: 1.0
# Sample 69440: True label: 0.0, Predicted label: 0.0
# Sample 69520: True label: 1.0, Predicted label: 1.0
# Sample 69600: True label: 1.0, Predicted label: 1.0
# Sample 69680: True label: 1.0, Predicted label: 1.0
# Sample 69760: True label: 1.0, Predicted label: 1.0
# Sample 69840: True label: 1.0, Predicted label: 1.0
# Sample 69920: True label: 1.0, Predicted label: 1.0
# Sample 70000: True label: 1.0, Predicted label: 1.0
# Sample 70080: True label: 1.0, Predicted label: 1.0
# Sample 70160: True label: 1.0, Predicted label: 1.0
# Sample 70240: True label: 1.0, Predicted label: 1.0
# Sample 70320: True label: 1.0, Predicted label: 1.0
# Sample 70400: True label: 1.0, Predicted label: 1.0
# Sample 70480: True label: 1.0, Predicted label: 1.0
# Sample 70560: True label: 1.0, Predicted label: 1.0
# Sample 70640: True label: 1.0, Predicted label: 1.0
# Sample 70720: True label: 0.0, Predicted label: 0.0
# Sample 70800: True label: 1.0, Predicted label: 1.0
# Sample 70880: True label: 1.0, Predicted label: 1.0
# Sample 70960: True label: 1.0, Predicted label: 1.0
# Sample 71040: True label: 1.0, Predicted label: 1.0
# Sample 71120: True label: 1.0, Predicted label: 1.0
# Sample 71200: True label: 1.0, Predicted label: 1.0
# Sample 71280: True label: 1.0, Predicted label: 1.0
# Sample 71360: True label: 1.0, Predicted label: 1.0
# Sample 71440: True label: 1.0, Predicted label: 1.0
# Sample 71520: True label: 1.0, Predicted label: 1.0
# Sample 71600: True label: 1.0, Predicted label: 1.0
# Sample 71680: True label: 0.0, Predicted label: 0.0
# Sample 71760: True label: 1.0, Predicted label: 1.0
# Sample 71840: True label: 1.0, Predicted label: 1.0
# Sample 71920: True label: 1.0, Predicted label: 1.0
# Sample 72000: True label: 1.0, Predicted label: 1.0
# Sample 72080: True label: 1.0, Predicted label: 1.0
# Sample 72160: True label: 1.0, Predicted label: 1.0
# Sample 72240: True label: 1.0, Predicted label: 1.0
# Sample 72320: True label: 1.0, Predicted label: 1.0
# Sample 72400: True label: 1.0, Predicted label: 1.0
# Sample 72480: True label: 1.0, Predicted label: 1.0
# Sample 72560: True label: 1.0, Predicted label: 1.0
# Sample 72640: True label: 0.0, Predicted label: 0.0
# Sample 72720: True label: 1.0, Predicted label: 1.0
# Sample 72800: True label: 1.0, Predicted label: 1.0
# Sample 72880: True label: 1.0, Predicted label: 1.0
# Sample 72960: True label: 1.0, Predicted label: 1.0
# Sample 73040: True label: 1.0, Predicted label: 1.0
# Sample 73120: True label: 1.0, Predicted label: 1.0
# Sample 73200: True label: 1.0, Predicted label: 1.0
# Sample 73280: True label: 1.0, Predicted label: 1.0
# Sample 73360: True label: 1.0, Predicted label: 1.0
# Sample 73440: True label: 0.0, Predicted label: 0.0
# Sample 73520: True label: 0.0, Predicted label: 0.0
# Sample 73600: True label: 0.0, Predicted label: 0.0
# Sample 73680: True label: 1.0, Predicted label: 1.0
# Sample 73760: True label: 1.0, Predicted label: 1.0
# Sample 73840: True label: 1.0, Predicted label: 1.0
# Sample 73920: True label: 1.0, Predicted label: 1.0
# Sample 74000: True label: 1.0, Predicted label: 1.0
# Sample 74080: True label: 0.0, Predicted label: 0.0
# Sample 74160: True label: 1.0, Predicted label: 1.0
# Sample 74240: True label: 1.0, Predicted label: 1.0
# Sample 74320: True label: 1.0, Predicted label: 1.0
# Sample 74400: True label: 1.0, Predicted label: 1.0
# Sample 74480: True label: 0.0, Predicted label: 0.0
# Sample 74560: True label: 1.0, Predicted label: 1.0
# Sample 74640: True label: 0.0, Predicted label: 0.0
# Sample 74720: True label: 1.0, Predicted label: 1.0
# Sample 74800: True label: 1.0, Predicted label: 1.0
# Sample 74880: True label: 1.0, Predicted label: 1.0
# Sample 74960: True label: 0.0, Predicted label: 1.0
# Sample 75040: True label: 1.0, Predicted label: 1.0
# Sample 75120: True label: 1.0, Predicted label: 1.0
# Sample 75200: True label: 1.0, Predicted label: 1.0
# Sample 75280: True label: 1.0, Predicted label: 1.0
# Sample 75360: True label: 1.0, Predicted label: 1.0
# Sample 75440: True label: 1.0, Predicted label: 1.0
# Sample 75520: True label: 1.0, Predicted label: 1.0
# Sample 75600: True label: 1.0, Predicted label: 1.0
# Sample 75680: True label: 1.0, Predicted label: 1.0
# Sample 75760: True label: 1.0, Predicted label: 1.0
# Sample 75840: True label: 1.0, Predicted label: 1.0
# Sample 75920: True label: 1.0, Predicted label: 1.0
# Sample 76000: True label: 0.0, Predicted label: 0.0
# Sample 76080: True label: 1.0, Predicted label: 1.0
# Sample 76160: True label: 0.0, Predicted label: 0.0
# Sample 76240: True label: 1.0, Predicted label: 1.0
# Sample 76320: True label: 1.0, Predicted label: 1.0
# Sample 76400: True label: 1.0, Predicted label: 1.0
# Sample 76480: True label: 1.0, Predicted label: 1.0
# Sample 76560: True label: 1.0, Predicted label: 1.0
# Sample 76640: True label: 1.0, Predicted label: 1.0
# Sample 76720: True label: 1.0, Predicted label: 1.0
# Sample 76800: True label: 0.0, Predicted label: 1.0
# Sample 76880: True label: 1.0, Predicted label: 1.0
# Sample 76960: True label: 1.0, Predicted label: 1.0
# Sample 77040: True label: 1.0, Predicted label: 1.0
# Sample 77120: True label: 0.0, Predicted label: 0.0
# Sample 77200: True label: 1.0, Predicted label: 1.0
# Sample 77280: True label: 1.0, Predicted label: 1.0
# Sample 77360: True label: 1.0, Predicted label: 1.0
# Sample 77440: True label: 1.0, Predicted label: 1.0
# Sample 77520: True label: 1.0, Predicted label: 1.0
# Sample 77600: True label: 1.0, Predicted label: 1.0
# Sample 77680: True label: 1.0, Predicted label: 1.0
# Sample 77760: True label: 1.0, Predicted label: 1.0
# Sample 77840: True label: 0.0, Predicted label: 1.0
# Sample 77920: True label: 1.0, Predicted label: 1.0
# Sample 78000: True label: 1.0, Predicted label: 1.0
# Sample 78080: True label: 1.0, Predicted label: 1.0
# Sample 78160: True label: 0.0, Predicted label: 0.0
# Sample 78240: True label: 1.0, Predicted label: 1.0
# Sample 78320: True label: 0.0, Predicted label: 1.0
# Sample 78400: True label: 1.0, Predicted label: 1.0
# Sample 78480: True label: 1.0, Predicted label: 1.0
# Sample 78560: True label: 1.0, Predicted label: 1.0
# Sample 78640: True label: 1.0, Predicted label: 1.0
# Sample 78720: True label: 0.0, Predicted label: 0.0
# Sample 78800: True label: 1.0, Predicted label: 1.0
# Sample 78880: True label: 1.0, Predicted label: 1.0
# Accuracy: 93.92%
# Precision: 93.47%
# Recall: 99.77000000000001%
# F1-score: 96.52%
# CPU times: total: 41.8 s
# Wall time: 53.5 s

# %%
# %%time
# Use the Hoeffding Tree (HT) model 
name5 = "SRP Model"
model5 = ensemble.SRPClassifier() # Define the model
t, m5 = adaptive_learning(model5, X_train, y_train, X_test, y_test) # Learn the model on the dataset
acc_fig(t, m5, name5) # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# Sample 0: True label: 1.0, Predicted label: 1.0
# Sample 80: True label: 0.0, Predicted label: 1.0
# Sample 160: True label: 1.0, Predicted label: 1.0
# Sample 240: True label: 1.0, Predicted label: 1.0
# Sample 320: True label: 1.0, Predicted label: 1.0
# Sample 400: True label: 1.0, Predicted label: 1.0
# Sample 480: True label: 1.0, Predicted label: 1.0
# Sample 560: True label: 1.0, Predicted label: 1.0
# Sample 640: True label: 1.0, Predicted label: 1.0
# Sample 720: True label: 0.0, Predicted label: 1.0
# Sample 800: True label: 0.0, Predicted label: 0.0
# Sample 880: True label: 1.0, Predicted label: 1.0
# Sample 960: True label: 0.0, Predicted label: 1.0
# Sample 1040: True label: 1.0, Predicted label: 1.0
# Sample 1120: True label: 1.0, Predicted label: 1.0
# Sample 1200: True label: 1.0, Predicted label: 1.0
# Sample 1280: True label: 1.0, Predicted label: 1.0
# Sample 1360: True label: 1.0, Predicted label: 1.0
# Sample 1440: True label: 1.0, Predicted label: 1.0
# Sample 1520: True label: 1.0, Predicted label: 1.0
# Sample 1600: True label: 0.0, Predicted label: 0.0
# Sample 1680: True label: 1.0, Predicted label: 1.0
# Sample 1760: True label: 1.0, Predicted label: 1.0
# Sample 1840: True label: 1.0, Predicted label: 1.0
# Sample 1920: True label: 1.0, Predicted label: 1.0
# Sample 2000: True label: 1.0, Predicted label: 1.0
# Sample 2080: True label: 1.0, Predicted label: 1.0
# Sample 2160: True label: 1.0, Predicted label: 1.0
# Sample 2240: True label: 1.0, Predicted label: 1.0
# Sample 2320: True label: 1.0, Predicted label: 1.0
# Sample 2400: True label: 1.0, Predicted label: 1.0
# Sample 2480: True label: 0.0, Predicted label: 0.0
# Sample 2560: True label: 1.0, Predicted label: 1.0
# Sample 2640: True label: 1.0, Predicted label: 1.0
# Sample 2720: True label: 1.0, Predicted label: 1.0
# Sample 2800: True label: 1.0, Predicted label: 1.0
# Sample 2880: True label: 1.0, Predicted label: 1.0
# Sample 2960: True label: 1.0, Predicted label: 1.0
# Sample 3040: True label: 1.0, Predicted label: 1.0
# Sample 3120: True label: 1.0, Predicted label: 1.0
# Sample 3200: True label: 1.0, Predicted label: 1.0
# Sample 3280: True label: 0.0, Predicted label: 0.0
# Sample 3360: True label: 1.0, Predicted label: 1.0
# Sample 3440: True label: 0.0, Predicted label: 1.0
# Sample 3520: True label: 1.0, Predicted label: 1.0
# Sample 3600: True label: 1.0, Predicted label: 1.0
# Sample 3680: True label: 0.0, Predicted label: 0.0
# Sample 3760: True label: 1.0, Predicted label: 1.0
# Sample 3840: True label: 0.0, Predicted label: 0.0
# Sample 3920: True label: 1.0, Predicted label: 1.0
# Sample 4000: True label: 1.0, Predicted label: 1.0
# Sample 4080: True label: 1.0, Predicted label: 1.0
# Sample 4160: True label: 1.0, Predicted label: 1.0
# Sample 4240: True label: 1.0, Predicted label: 1.0
# Sample 4320: True label: 1.0, Predicted label: 1.0
# Sample 4400: True label: 0.0, Predicted label: 0.0
# Sample 4480: True label: 1.0, Predicted label: 1.0
# Sample 4560: True label: 1.0, Predicted label: 1.0
# Sample 4640: True label: 1.0, Predicted label: 1.0
# Sample 4720: True label: 1.0, Predicted label: 1.0
# Sample 4800: True label: 1.0, Predicted label: 1.0
# Sample 4880: True label: 1.0, Predicted label: 1.0
# Sample 4960: True label: 1.0, Predicted label: 1.0
# Sample 5040: True label: 1.0, Predicted label: 1.0
# Sample 5120: True label: 1.0, Predicted label: 1.0
# Sample 5200: True label: 1.0, Predicted label: 1.0
# Sample 5280: True label: 1.0, Predicted label: 1.0
# Sample 5360: True label: 1.0, Predicted label: 1.0
# Sample 5440: True label: 1.0, Predicted label: 1.0
# Sample 5520: True label: 1.0, Predicted label: 1.0
# Sample 5600: True label: 1.0, Predicted label: 1.0
# Sample 5680: True label: 1.0, Predicted label: 1.0
# Sample 5760: True label: 1.0, Predicted label: 1.0
# Sample 5840: True label: 1.0, Predicted label: 1.0
# Sample 5920: True label: 0.0, Predicted label: 0.0
# Sample 6000: True label: 1.0, Predicted label: 1.0
# Sample 6080: True label: 1.0, Predicted label: 1.0
# Sample 6160: True label: 1.0, Predicted label: 1.0
# Sample 6240: True label: 1.0, Predicted label: 1.0
# Sample 6320: True label: 1.0, Predicted label: 1.0
# Sample 6400: True label: 1.0, Predicted label: 1.0
# Sample 6480: True label: 1.0, Predicted label: 1.0
# Sample 6560: True label: 0.0, Predicted label: 0.0
# Sample 6640: True label: 1.0, Predicted label: 1.0
# Sample 6720: True label: 0.0, Predicted label: 1.0
# Sample 6800: True label: 1.0, Predicted label: 1.0
# Sample 6880: True label: 1.0, Predicted label: 1.0
# Sample 6960: True label: 0.0, Predicted label: 1.0
# Sample 7040: True label: 1.0, Predicted label: 1.0
# Sample 7120: True label: 1.0, Predicted label: 1.0
# Sample 7200: True label: 1.0, Predicted label: 1.0
# Sample 7280: True label: 1.0, Predicted label: 1.0
# Sample 7360: True label: 1.0, Predicted label: 1.0
# Sample 7440: True label: 1.0, Predicted label: 1.0
# Sample 7520: True label: 0.0, Predicted label: 0.0
# Sample 7600: True label: 1.0, Predicted label: 1.0
# Sample 7680: True label: 1.0, Predicted label: 1.0
# Sample 7760: True label: 1.0, Predicted label: 1.0
# Sample 7840: True label: 1.0, Predicted label: 1.0
# Sample 7920: True label: 1.0, Predicted label: 1.0
# Sample 8000: True label: 1.0, Predicted label: 1.0
# Sample 8080: True label: 1.0, Predicted label: 1.0
# Sample 8160: True label: 1.0, Predicted label: 1.0
# Sample 8240: True label: 1.0, Predicted label: 1.0
# Sample 8320: True label: 1.0, Predicted label: 1.0
# Sample 8400: True label: 1.0, Predicted label: 1.0
# Sample 8480: True label: 1.0, Predicted label: 1.0
# Sample 8560: True label: 0.0, Predicted label: 0.0
# Sample 8640: True label: 1.0, Predicted label: 1.0
# Sample 8720: True label: 1.0, Predicted label: 1.0
# Sample 8800: True label: 1.0, Predicted label: 1.0
# Sample 8880: True label: 1.0, Predicted label: 1.0
# Sample 8960: True label: 1.0, Predicted label: 1.0
# Sample 9040: True label: 1.0, Predicted label: 1.0
# Sample 9120: True label: 1.0, Predicted label: 1.0
# Sample 9200: True label: 1.0, Predicted label: 1.0
# Sample 9280: True label: 1.0, Predicted label: 1.0
# Sample 9360: True label: 1.0, Predicted label: 1.0
# Sample 9440: True label: 1.0, Predicted label: 1.0
# Sample 9520: True label: 1.0, Predicted label: 1.0
# Sample 9600: True label: 1.0, Predicted label: 1.0
# Sample 9680: True label: 0.0, Predicted label: 1.0
# Sample 9760: True label: 1.0, Predicted label: 1.0
# Sample 9840: True label: 1.0, Predicted label: 1.0
# Sample 9920: True label: 1.0, Predicted label: 1.0
# Sample 10000: True label: 1.0, Predicted label: 1.0
# Sample 10080: True label: 1.0, Predicted label: 1.0
# Sample 10160: True label: 1.0, Predicted label: 1.0
# Sample 10240: True label: 1.0, Predicted label: 1.0
# Sample 10320: True label: 1.0, Predicted label: 1.0
# Sample 10400: True label: 1.0, Predicted label: 1.0
# Sample 10480: True label: 1.0, Predicted label: 1.0
# Sample 10560: True label: 1.0, Predicted label: 1.0
# Sample 10640: True label: 0.0, Predicted label: 0.0
# Sample 10720: True label: 1.0, Predicted label: 1.0
# Sample 10800: True label: 1.0, Predicted label: 1.0
# Sample 10880: True label: 1.0, Predicted label: 1.0
# Sample 10960: True label: 1.0, Predicted label: 1.0
# Sample 11040: True label: 1.0, Predicted label: 1.0
# Sample 11120: True label: 1.0, Predicted label: 1.0
# Sample 11200: True label: 1.0, Predicted label: 1.0
# Sample 11280: True label: 0.0, Predicted label: 0.0
# Sample 11360: True label: 1.0, Predicted label: 1.0
# Sample 11440: True label: 1.0, Predicted label: 1.0
# Sample 11520: True label: 1.0, Predicted label: 1.0
# Sample 11600: True label: 1.0, Predicted label: 1.0
# Sample 11680: True label: 0.0, Predicted label: 0.0
# Sample 11760: True label: 1.0, Predicted label: 1.0
# Sample 11840: True label: 1.0, Predicted label: 1.0
# Sample 11920: True label: 1.0, Predicted label: 1.0
# Sample 12000: True label: 1.0, Predicted label: 1.0
# Sample 12080: True label: 1.0, Predicted label: 1.0
# Sample 12160: True label: 1.0, Predicted label: 1.0
# Sample 12240: True label: 1.0, Predicted label: 1.0
# Sample 12320: True label: 1.0, Predicted label: 1.0
# Sample 12400: True label: 1.0, Predicted label: 1.0
# Sample 12480: True label: 1.0, Predicted label: 1.0
# Sample 12560: True label: 1.0, Predicted label: 1.0
# Sample 12640: True label: 0.0, Predicted label: 0.0
# Sample 12720: True label: 0.0, Predicted label: 0.0
# Sample 12800: True label: 1.0, Predicted label: 1.0
# Sample 12880: True label: 0.0, Predicted label: 0.0
# Sample 12960: True label: 1.0, Predicted label: 1.0
# Sample 13040: True label: 1.0, Predicted label: 1.0
# Sample 13120: True label: 1.0, Predicted label: 1.0
# Sample 13200: True label: 1.0, Predicted label: 1.0
# Sample 13280: True label: 0.0, Predicted label: 0.0
# Sample 13360: True label: 1.0, Predicted label: 1.0
# Sample 13440: True label: 0.0, Predicted label: 0.0
# Sample 13520: True label: 1.0, Predicted label: 1.0
# Sample 13600: True label: 1.0, Predicted label: 1.0
# Sample 13680: True label: 1.0, Predicted label: 1.0
# Sample 13760: True label: 0.0, Predicted label: 0.0
# Sample 13840: True label: 1.0, Predicted label: 1.0
# Sample 13920: True label: 1.0, Predicted label: 1.0
# Warning detected at index 15093
# Warning detected at index 15094
# Warning detected at index 15095
# Warning detected at index 15096
# Warning detected at index 15097
# Warning detected at index 15098
# Warning detected at index 15099
# Warning detected at index 15100
# Warning detected at index 15101
# Warning detected at index 15102
# Warning detected at index 15103
# Warning detected at index 15104
# Warning detected at index 15105
# Warning detected at index 15106
# Warning detected at index 15107
# Warning detected at index 15108
# Warning detected at index 15109
# Change detected at index 15110, input value: 1.0
# Warning detected at index 15110
# Change detected at index 15111, input value: 1.0
# Warning detected at index 15111
# Change detected at index 15112, input value: 1.0
# Warning detected at index 15112
# Change detected at index 15113, input value: 1.0
# Warning detected at index 15113
# Change detected at index 15114, input value: 1.0
# Warning detected at index 15114
# Change detected at index 15115, input value: 1.0
# Warning detected at index 15115
# Change detected at index 15116, input value: 1.0
# Warning detected at index 15116
# Change detected at index 15117, input value: 1.0
# Warning detected at index 15117
# Change detected at index 15118, input value: 1.0
# Warning detected at index 15118
# Change detected at index 15119, input value: 1.0
# Warning detected at index 15119
# Change detected at index 15120, input value: 1.0
# Warning detected at index 15120
# Sample 15120: True label: 1.0, Predicted label: 1.0
# Change detected at index 15121, input value: 1.0
# Warning detected at index 15121
# Change detected at index 15122, input value: 1.0
# Warning detected at index 15122
# Change detected at index 15123, input value: 0.0
# Warning detected at index 15123
# Change detected at index 15124, input value: 0.0
# Warning detected at index 15124
# Change detected at index 15125, input value: 1.0
# Warning detected at index 15125
# Change detected at index 15126, input value: 1.0
# Warning detected at index 15126
# Change detected at index 15127, input value: 1.0
# Warning detected at index 15127
# Change detected at index 15128, input value: 1.0
# Warning detected at index 15128
# Change detected at index 15129, input value: 1.0
# Warning detected at index 15129
# Change detected at index 15130, input value: 1.0
# Warning detected at index 15130
# Change detected at index 15131, input value: 1.0
# Warning detected at index 15131
# Change detected at index 15132, input value: 1.0
# Warning detected at index 15132
# Change detected at index 15133, input value: 1.0
# Warning detected at index 15133
# Change detected at index 15134, input value: 1.0
# Warning detected at index 15134
# Change detected at index 15135, input value: 1.0
# Warning detected at index 15135
# Change detected at index 15136, input value: 1.0
# Warning detected at index 15136
# Change detected at index 15137, input value: 0.0
# Warning detected at index 15137
# Change detected at index 15138, input value: 1.0
# Warning detected at index 15138
# Change detected at index 15139, input value: 1.0
# Warning detected at index 15139
# Change detected at index 15140, input value: 1.0
# Warning detected at index 15140
# Change detected at index 15141, input value: 1.0
# Warning detected at index 15141
# Change detected at index 15142, input value: 0.0
# Warning detected at index 15142
# Change detected at index 15143, input value: 1.0
# Warning detected at index 15143
# Change detected at index 15144, input value: 1.0
# Warning detected at index 15144
# Change detected at index 15145, input value: 1.0
# Warning detected at index 15145
# Change detected at index 15146, input value: 1.0
# Warning detected at index 15146
# Change detected at index 15147, input value: 1.0
# Warning detected at index 15147
# Change detected at index 15148, input value: 1.0
# Warning detected at index 15148
# Change detected at index 15149, input value: 1.0
# Warning detected at index 15149
# Change detected at index 15150, input value: 1.0
# Warning detected at index 15150
# Change detected at index 15151, input value: 0.0
# Warning detected at index 15151
# Change detected at index 15152, input value: 1.0
# Warning detected at index 15152
# Change detected at index 15153, input value: 1.0
# Warning detected at index 15153
# Change detected at index 15154, input value: 1.0
# Warning detected at index 15154
# Change detected at index 15155, input value: 1.0
# Warning detected at index 15155
# Change detected at index 15156, input value: 0.0
# Warning detected at index 15156
# Change detected at index 15157, input value: 1.0
# Warning detected at index 15157
# Change detected at index 15158, input value: 1.0
# Warning detected at index 15158
# Change detected at index 15159, input value: 1.0
# Warning detected at index 15159
# Change detected at index 15160, input value: 1.0
# Warning detected at index 15160
# Change detected at index 15161, input value: 1.0
# Warning detected at index 15161
# Change detected at index 15162, input value: 1.0
# Warning detected at index 15162
# Change detected at index 15163, input value: 1.0
# Warning detected at index 15163
# Change detected at index 15164, input value: 1.0
# Warning detected at index 15164
# Change detected at index 15165, input value: 0.0
# Warning detected at index 15165
# Change detected at index 15166, input value: 1.0
# Warning detected at index 15166
# Change detected at index 15167, input value: 1.0
# Warning detected at index 15167
# Change detected at index 15168, input value: 1.0
# Warning detected at index 15168
# Change detected at index 15169, input value: 1.0
# Warning detected at index 15169
# Change detected at index 15170, input value: 1.0
# Warning detected at index 15170
# Change detected at index 15171, input value: 1.0
# Warning detected at index 15171
# Change detected at index 15172, input value: 1.0
# Warning detected at index 15172
# Change detected at index 15173, input value: 0.0
# Warning detected at index 15173
# Change detected at index 15174, input value: 0.0
# Warning detected at index 15174
# Change detected at index 15175, input value: 1.0
# Warning detected at index 15175
# Change detected at index 15176, input value: 1.0
# Warning detected at index 15176
# Change detected at index 15177, input value: 1.0
# Warning detected at index 15177
# Change detected at index 15178, input value: 1.0
# Warning detected at index 15178
# Change detected at index 15179, input value: 1.0
# Warning detected at index 15179
# Change detected at index 15180, input value: 1.0
# Warning detected at index 15180
# Change detected at index 15181, input value: 1.0
# Warning detected at index 15181
# Change detected at index 15182, input value: 1.0
# Warning detected at index 15182
# Change detected at index 15183, input value: 1.0
# Warning detected at index 15183
# Change detected at index 15184, input value: 1.0
# Warning detected at index 15184
# Change detected at index 15185, input value: 1.0
# Warning detected at index 15185
# Change detected at index 15186, input value: 1.0
# Warning detected at index 15186
# Change detected at index 15187, input value: 0.0
# Warning detected at index 15187
# Change detected at index 15188, input value: 1.0
# Warning detected at index 15188
# Change detected at index 15189, input value: 0.0
# Warning detected at index 15189
# Change detected at index 15190, input value: 1.0
# Warning detected at index 15190
# Change detected at index 15191, input value: 1.0
# Warning detected at index 15191
# Change detected at index 15192, input value: 1.0
# Warning detected at index 15192
# Change detected at index 15193, input value: 1.0
# Warning detected at index 15193
# Change detected at index 15194, input value: 1.0
# Warning detected at index 15194
# Change detected at index 15195, input value: 0.0
# Warning detected at index 15195
# Change detected at index 15196, input value: 1.0
# Warning detected at index 15196
# Change detected at index 15197, input value: 1.0
# Warning detected at index 15197
# Change detected at index 15198, input value: 0.0
# Warning detected at index 15198
# Change detected at index 15199, input value: 0.0
# Warning detected at index 15199
# Change detected at index 15200, input value: 1.0
# Warning detected at index 15200
# Sample 15200: True label: 1.0, Predicted label: 1.0
# Change detected at index 15201, input value: 1.0
# Warning detected at index 15201
# Change detected at index 15202, input value: 1.0
# Warning detected at index 15202
# Change detected at index 15203, input value: 1.0
# Warning detected at index 15203
# Change detected at index 15204, input value: 1.0
# Warning detected at index 15204
# Change detected at index 15205, input value: 1.0
# Warning detected at index 15205
# Change detected at index 15206, input value: 1.0
# Warning detected at index 15206
# Change detected at index 15207, input value: 1.0
# Warning detected at index 15207
# Sample 15280: True label: 1.0, Predicted label: 1.0
# Sample 15360: True label: 1.0, Predicted label: 1.0
# Sample 15440: True label: 1.0, Predicted label: 1.0
# Sample 15520: True label: 1.0, Predicted label: 1.0
# Sample 15600: True label: 1.0, Predicted label: 1.0
# Sample 15680: True label: 0.0, Predicted label: 0.0
# Sample 15760: True label: 1.0, Predicted label: 1.0
# Sample 15840: True label: 1.0, Predicted label: 1.0
# Sample 15920: True label: 1.0, Predicted label: 1.0
# Sample 16000: True label: 1.0, Predicted label: 1.0
# Sample 16080: True label: 0.0, Predicted label: 0.0
# Sample 16160: True label: 1.0, Predicted label: 1.0
# Sample 16240: True label: 1.0, Predicted label: 1.0
# Sample 16320: True label: 0.0, Predicted label: 1.0
# Sample 16400: True label: 1.0, Predicted label: 1.0
# Sample 16480: True label: 1.0, Predicted label: 1.0
# Sample 16560: True label: 1.0, Predicted label: 1.0
# Sample 16640: True label: 1.0, Predicted label: 1.0
# Sample 16720: True label: 1.0, Predicted label: 1.0
# Sample 16800: True label: 0.0, Predicted label: 0.0
# Sample 16880: True label: 0.0, Predicted label: 1.0
# Sample 16960: True label: 0.0, Predicted label: 0.0
# Sample 17040: True label: 0.0, Predicted label: 0.0
# Sample 17120: True label: 1.0, Predicted label: 1.0
# Sample 17200: True label: 1.0, Predicted label: 1.0
# Sample 17280: True label: 1.0, Predicted label: 1.0
# Sample 17360: True label: 0.0, Predicted label: 0.0
# Sample 17440: True label: 1.0, Predicted label: 1.0
# Sample 17520: True label: 1.0, Predicted label: 1.0
# Sample 17600: True label: 1.0, Predicted label: 1.0
# Sample 17680: True label: 1.0, Predicted label: 1.0
# Sample 17760: True label: 1.0, Predicted label: 1.0
# Sample 17840: True label: 1.0, Predicted label: 1.0
# Sample 17920: True label: 1.0, Predicted label: 1.0
# Sample 18000: True label: 1.0, Predicted label: 1.0
# Sample 18080: True label: 1.0, Predicted label: 1.0
# Sample 18160: True label: 1.0, Predicted label: 1.0
# Sample 18240: True label: 1.0, Predicted label: 1.0
# Sample 18320: True label: 0.0, Predicted label: 0.0
# Sample 18400: True label: 1.0, Predicted label: 1.0
# Sample 18480: True label: 0.0, Predicted label: 1.0
# Sample 18560: True label: 1.0, Predicted label: 1.0
# Sample 18640: True label: 0.0, Predicted label: 0.0
# Sample 18720: True label: 1.0, Predicted label: 1.0
# Sample 18800: True label: 1.0, Predicted label: 1.0
# Sample 18880: True label: 1.0, Predicted label: 1.0
# Sample 18960: True label: 1.0, Predicted label: 1.0
# Sample 19040: True label: 0.0, Predicted label: 0.0
# Sample 19120: True label: 1.0, Predicted label: 1.0
# Sample 19200: True label: 1.0, Predicted label: 1.0
# Sample 19280: True label: 0.0, Predicted label: 0.0
# Sample 19360: True label: 1.0, Predicted label: 1.0
# Sample 19440: True label: 1.0, Predicted label: 1.0
# Sample 19520: True label: 1.0, Predicted label: 1.0
# Sample 19600: True label: 1.0, Predicted label: 1.0
# Sample 19680: True label: 1.0, Predicted label: 1.0
# Sample 19760: True label: 1.0, Predicted label: 1.0
# Sample 19840: True label: 1.0, Predicted label: 1.0
# Sample 19920: True label: 1.0, Predicted label: 1.0
# Sample 20000: True label: 1.0, Predicted label: 1.0
# Sample 20080: True label: 1.0, Predicted label: 1.0
# Sample 20160: True label: 0.0, Predicted label: 0.0
# Sample 20240: True label: 1.0, Predicted label: 1.0
# Sample 20320: True label: 0.0, Predicted label: 0.0
# Sample 20400: True label: 1.0, Predicted label: 1.0
# Sample 20480: True label: 1.0, Predicted label: 1.0
# Sample 20560: True label: 1.0, Predicted label: 1.0
# Sample 20640: True label: 1.0, Predicted label: 1.0
# Sample 20720: True label: 1.0, Predicted label: 1.0
# Sample 20800: True label: 1.0, Predicted label: 1.0
# Sample 20880: True label: 1.0, Predicted label: 1.0
# Sample 20960: True label: 1.0, Predicted label: 1.0
# Sample 21040: True label: 1.0, Predicted label: 1.0
# Sample 21120: True label: 1.0, Predicted label: 1.0
# Sample 21200: True label: 1.0, Predicted label: 1.0
# Sample 21280: True label: 1.0, Predicted label: 1.0
# Sample 21360: True label: 1.0, Predicted label: 1.0
# Sample 21440: True label: 0.0, Predicted label: 0.0
# Sample 21520: True label: 1.0, Predicted label: 1.0
# Sample 21600: True label: 1.0, Predicted label: 1.0
# Sample 21680: True label: 1.0, Predicted label: 1.0
# Sample 21760: True label: 1.0, Predicted label: 1.0
# Sample 21840: True label: 1.0, Predicted label: 1.0
# Sample 21920: True label: 0.0, Predicted label: 1.0
# Sample 22000: True label: 1.0, Predicted label: 1.0
# Sample 22080: True label: 1.0, Predicted label: 1.0
# Sample 22160: True label: 1.0, Predicted label: 1.0
# Sample 22240: True label: 1.0, Predicted label: 1.0
# Sample 22320: True label: 1.0, Predicted label: 1.0
# Sample 22400: True label: 1.0, Predicted label: 1.0
# Sample 22480: True label: 0.0, Predicted label: 0.0
# Sample 22560: True label: 1.0, Predicted label: 1.0
# Sample 22640: True label: 1.0, Predicted label: 1.0
# Sample 22720: True label: 1.0, Predicted label: 1.0
# Sample 22800: True label: 1.0, Predicted label: 1.0
# Sample 22880: True label: 1.0, Predicted label: 1.0
# Sample 22960: True label: 1.0, Predicted label: 1.0
# Sample 23040: True label: 1.0, Predicted label: 1.0
# Sample 23120: True label: 1.0, Predicted label: 1.0
# Sample 23200: True label: 1.0, Predicted label: 1.0
# Sample 23280: True label: 0.0, Predicted label: 0.0
# Sample 23360: True label: 1.0, Predicted label: 1.0
# Sample 23440: True label: 1.0, Predicted label: 1.0
# Sample 23520: True label: 1.0, Predicted label: 1.0
# Sample 23600: True label: 1.0, Predicted label: 1.0
# Sample 23680: True label: 1.0, Predicted label: 1.0
# Sample 23760: True label: 1.0, Predicted label: 1.0
# Sample 23840: True label: 1.0, Predicted label: 1.0
# Sample 23920: True label: 1.0, Predicted label: 1.0
# Sample 24000: True label: 1.0, Predicted label: 1.0
# Sample 24080: True label: 1.0, Predicted label: 1.0
# Sample 24160: True label: 1.0, Predicted label: 1.0
# Sample 24240: True label: 1.0, Predicted label: 1.0
# Sample 24320: True label: 1.0, Predicted label: 1.0
# Sample 24400: True label: 1.0, Predicted label: 1.0
# ...
# Warning detected at index 68881
# Warning detected at index 68882
# Warning detected at index 68883
# Warning detected at index 68884
# Warning detected at index 68885
# Warning detected at index 68886
# Warning detected at index 68887
# Warning detected at index 68888
# Warning detected at index 68889
# Warning detected at index 68890
# Warning detected at index 68891
# Warning detected at index 68892
# Warning detected at index 68893
# Warning detected at index 68894
# Warning detected at index 68895
# Warning detected at index 68896
# Warning detected at index 68897
# Warning detected at index 68898
# Warning detected at index 68899
# Warning detected at index 68900
# Warning detected at index 68901
# Warning detected at index 68902
# Warning detected at index 68903
# Warning detected at index 68904
# Warning detected at index 68905
# Warning detected at index 68906
# Warning detected at index 68907
# Warning detected at index 68908
# Warning detected at index 68909
# Warning detected at index 68910
# Warning detected at index 68911
# Warning detected at index 68912
# Warning detected at index 68913
# Warning detected at index 68914
# Warning detected at index 68915
# Warning detected at index 68916
# Warning detected at index 68917
# Warning detected at index 68918
# Warning detected at index 68919
# Warning detected at index 68920
# Warning detected at index 68921
# Warning detected at index 68922
# Warning detected at index 68923
# Warning detected at index 68924
# Warning detected at index 68925
# Warning detected at index 68926
# Warning detected at index 68927
# Warning detected at index 68928
# Warning detected at index 68929
# Warning detected at index 68930
# Warning detected at index 68931
# Warning detected at index 68932
# Warning detected at index 68933
# Warning detected at index 68934
# Warning detected at index 68935
# Warning detected at index 68936
# Warning detected at index 68937
# Warning detected at index 68938
# Warning detected at index 68939
# Warning detected at index 68940
# Warning detected at index 68941
# Warning detected at index 68942
# Warning detected at index 68943
# Warning detected at index 68944
# Warning detected at index 68945
# Warning detected at index 68946
# Warning detected at index 68947
# Warning detected at index 68948
# Warning detected at index 68949
# Warning detected at index 68950
# Warning detected at index 68951
# Warning detected at index 68952
# Warning detected at index 68953
# Warning detected at index 68954
# Warning detected at index 68955
# Warning detected at index 68956
# Warning detected at index 68957
# Warning detected at index 68958
# Warning detected at index 68959
# Warning detected at index 68960
# Sample 68960: True label: 0.0, Predicted label: 0.0
# Warning detected at index 68961
# Warning detected at index 68962
# Warning detected at index 68963
# Warning detected at index 68964
# Warning detected at index 68965
# Warning detected at index 68966
# Warning detected at index 68967
# Warning detected at index 68968
# Warning detected at index 68969
# Warning detected at index 68970
# Warning detected at index 68971
# Warning detected at index 68972
# Warning detected at index 68973
# Warning detected at index 68974
# Warning detected at index 68975
# Warning detected at index 68976
# Warning detected at index 68977
# Warning detected at index 68978
# Warning detected at index 68979
# Warning detected at index 68980
# Warning detected at index 68981
# Warning detected at index 68982
# Warning detected at index 68983
# Warning detected at index 68984
# Warning detected at index 68985
# Warning detected at index 68986
# Warning detected at index 68987
# Warning detected at index 68988
# Warning detected at index 68989
# Warning detected at index 68990
# Warning detected at index 68991
# Warning detected at index 68992
# Warning detected at index 68993
# Warning detected at index 68994
# Warning detected at index 68995
# Warning detected at index 68996
# Warning detected at index 68997
# Warning detected at index 68998
# Warning detected at index 68999
# Warning detected at index 69000
# Warning detected at index 69001
# Warning detected at index 69002
# Warning detected at index 69003
# Warning detected at index 69004
# Warning detected at index 69005
# Warning detected at index 69006
# Warning detected at index 69007
# Warning detected at index 69008
# Warning detected at index 69009
# Warning detected at index 69010
# Warning detected at index 69011
# Warning detected at index 69012
# Warning detected at index 69013
# Warning detected at index 69014
# Warning detected at index 69015
# Warning detected at index 69016
# Warning detected at index 69017
# Warning detected at index 69018
# Warning detected at index 69019
# Warning detected at index 69020
# Warning detected at index 69021
# Warning detected at index 69022
# Warning detected at index 69023
# Warning detected at index 69024
# Warning detected at index 69025
# Warning detected at index 69026
# Warning detected at index 69027
# Warning detected at index 69028
# Warning detected at index 69029
# Warning detected at index 69030
# Warning detected at index 69031
# Warning detected at index 69032
# Warning detected at index 69033
# Warning detected at index 69034
# Warning detected at index 69035
# Warning detected at index 69036
# Warning detected at index 69037
# Warning detected at index 69038
# Warning detected at index 69039
# Warning detected at index 69040
# Sample 69040: True label: 1.0, Predicted label: 1.0
# Warning detected at index 69041
# Warning detected at index 69042
# Warning detected at index 69043
# Warning detected at index 69044
# Warning detected at index 69045
# Warning detected at index 69046
# Warning detected at index 69047
# Warning detected at index 69048
# Warning detected at index 69049
# Warning detected at index 69050
# Warning detected at index 69051
# Warning detected at index 69052
# Warning detected at index 69053
# Warning detected at index 69054
# Warning detected at index 69055
# Warning detected at index 69056
# Warning detected at index 69057
# Warning detected at index 69058
# Warning detected at index 69059
# Warning detected at index 69060
# Warning detected at index 69061
# Warning detected at index 69062
# Warning detected at index 69063
# Warning detected at index 69064
# Warning detected at index 69065
# Warning detected at index 69066
# Warning detected at index 69067
# Warning detected at index 69068
# Warning detected at index 69069
# Warning detected at index 69070
# Warning detected at index 69071
# Warning detected at index 69072
# Warning detected at index 69073
# Warning detected at index 69074
# Warning detected at index 69075
# Warning detected at index 69076
# Change detected at index 69077, input value: 1.0
# Warning detected at index 69077
# Change detected at index 69078, input value: 1.0
# Warning detected at index 69078
# Change detected at index 69079, input value: 1.0
# Warning detected at index 69079
# Change detected at index 69080, input value: 1.0
# Warning detected at index 69080
# Change detected at index 69081, input value: 1.0
# Warning detected at index 69081
# Change detected at index 69082, input value: 1.0
# Warning detected at index 69082
# Change detected at index 69083, input value: 0.0
# Warning detected at index 69083
# Change detected at index 69084, input value: 1.0
# Warning detected at index 69084
# Change detected at index 69085, input value: 1.0
# Warning detected at index 69085
# Change detected at index 69086, input value: 1.0
# Warning detected at index 69086
# Change detected at index 69087, input value: 1.0
# Warning detected at index 69087
# Change detected at index 69088, input value: 1.0
# Warning detected at index 69088
# Change detected at index 69089, input value: 1.0
# Warning detected at index 69089
# Change detected at index 69090, input value: 1.0
# Warning detected at index 69090
# Change detected at index 69091, input value: 1.0
# Warning detected at index 69091
# Change detected at index 69092, input value: 1.0
# Warning detected at index 69092
# Change detected at index 69093, input value: 1.0
# Warning detected at index 69093
# Change detected at index 69094, input value: 1.0
# Warning detected at index 69094
# Change detected at index 69095, input value: 1.0
# Warning detected at index 69095
# Change detected at index 69096, input value: 1.0
# Warning detected at index 69096
# Change detected at index 69097, input value: 1.0
# Warning detected at index 69097
# Change detected at index 69098, input value: 1.0
# Warning detected at index 69098
# Change detected at index 69099, input value: 1.0
# Warning detected at index 69099
# Change detected at index 69100, input value: 1.0
# Warning detected at index 69100
# Change detected at index 69101, input value: 1.0
# Warning detected at index 69101
# Change detected at index 69102, input value: 1.0
# Warning detected at index 69102
# Change detected at index 69103, input value: 1.0
# Warning detected at index 69103
# Change detected at index 69104, input value: 1.0
# Warning detected at index 69104
# Change detected at index 69105, input value: 1.0
# Warning detected at index 69105
# Change detected at index 69106, input value: 1.0
# Warning detected at index 69106
# Change detected at index 69107, input value: 1.0
# Warning detected at index 69107
# Change detected at index 69108, input value: 1.0
# Warning detected at index 69108
# Change detected at index 69109, input value: 1.0
# Warning detected at index 69109
# Change detected at index 69110, input value: 1.0
# Warning detected at index 69110
# Change detected at index 69111, input value: 1.0
# Warning detected at index 69111
# Change detected at index 69112, input value: 1.0
# Warning detected at index 69112
# Change detected at index 69113, input value: 1.0
# Warning detected at index 69113
# Change detected at index 69114, input value: 1.0
# Warning detected at index 69114
# Sample 69120: True label: 0.0, Predicted label: 0.0
# Sample 69200: True label: 1.0, Predicted label: 1.0
# Sample 69280: True label: 1.0, Predicted label: 1.0
# Sample 69360: True label: 1.0, Predicted label: 1.0
# Sample 69440: True label: 0.0, Predicted label: 0.0
# Sample 69520: True label: 1.0, Predicted label: 1.0
# Sample 69600: True label: 1.0, Predicted label: 1.0
# Sample 69680: True label: 1.0, Predicted label: 1.0
# Sample 69760: True label: 1.0, Predicted label: 1.0
# Sample 69840: True label: 1.0, Predicted label: 1.0
# Sample 69920: True label: 1.0, Predicted label: 1.0
# Sample 70000: True label: 1.0, Predicted label: 1.0
# Sample 70080: True label: 1.0, Predicted label: 1.0
# Sample 70160: True label: 1.0, Predicted label: 1.0
# Sample 70240: True label: 1.0, Predicted label: 1.0
# Sample 70320: True label: 1.0, Predicted label: 1.0
# Sample 70400: True label: 1.0, Predicted label: 1.0
# Sample 70480: True label: 1.0, Predicted label: 1.0
# Sample 70560: True label: 1.0, Predicted label: 1.0
# Sample 70640: True label: 1.0, Predicted label: 1.0
# Sample 70720: True label: 0.0, Predicted label: 0.0
# Sample 70800: True label: 1.0, Predicted label: 1.0
# Sample 70880: True label: 1.0, Predicted label: 1.0
# Sample 70960: True label: 1.0, Predicted label: 1.0
# Sample 71040: True label: 1.0, Predicted label: 1.0
# Sample 71120: True label: 1.0, Predicted label: 1.0
# Sample 71200: True label: 1.0, Predicted label: 1.0
# Sample 71280: True label: 1.0, Predicted label: 1.0
# Sample 71360: True label: 1.0, Predicted label: 1.0
# Sample 71440: True label: 1.0, Predicted label: 1.0
# Sample 71520: True label: 1.0, Predicted label: 1.0
# Sample 71600: True label: 1.0, Predicted label: 1.0
# Sample 71680: True label: 0.0, Predicted label: 0.0
# Sample 71760: True label: 1.0, Predicted label: 1.0
# Sample 71840: True label: 1.0, Predicted label: 1.0
# Sample 71920: True label: 1.0, Predicted label: 1.0
# Sample 72000: True label: 1.0, Predicted label: 1.0
# Sample 72080: True label: 1.0, Predicted label: 1.0
# Sample 72160: True label: 1.0, Predicted label: 1.0
# Sample 72240: True label: 1.0, Predicted label: 1.0
# Sample 72320: True label: 1.0, Predicted label: 1.0
# Sample 72400: True label: 1.0, Predicted label: 1.0
# Sample 72480: True label: 1.0, Predicted label: 1.0
# Sample 72560: True label: 1.0, Predicted label: 1.0
# Sample 72640: True label: 0.0, Predicted label: 0.0
# Sample 72720: True label: 1.0, Predicted label: 1.0
# Sample 72800: True label: 1.0, Predicted label: 1.0
# Sample 72880: True label: 1.0, Predicted label: 1.0
# Sample 72960: True label: 1.0, Predicted label: 1.0
# Sample 73040: True label: 1.0, Predicted label: 1.0
# Sample 73120: True label: 1.0, Predicted label: 1.0
# Sample 73200: True label: 1.0, Predicted label: 1.0
# Sample 73280: True label: 1.0, Predicted label: 1.0
# Sample 73360: True label: 1.0, Predicted label: 1.0
# Sample 73440: True label: 0.0, Predicted label: 0.0
# Sample 73520: True label: 0.0, Predicted label: 0.0
# Sample 73600: True label: 0.0, Predicted label: 0.0
# Sample 73680: True label: 1.0, Predicted label: 1.0
# Sample 73760: True label: 1.0, Predicted label: 1.0
# Sample 73840: True label: 1.0, Predicted label: 1.0
# Sample 73920: True label: 1.0, Predicted label: 1.0
# Sample 74000: True label: 1.0, Predicted label: 1.0
# Sample 74080: True label: 0.0, Predicted label: 0.0
# Sample 74160: True label: 1.0, Predicted label: 1.0
# Sample 74240: True label: 1.0, Predicted label: 1.0
# Sample 74320: True label: 1.0, Predicted label: 1.0
# Sample 74400: True label: 1.0, Predicted label: 1.0
# Sample 74480: True label: 0.0, Predicted label: 0.0
# Sample 74560: True label: 1.0, Predicted label: 1.0
# Sample 74640: True label: 0.0, Predicted label: 0.0
# Sample 74720: True label: 1.0, Predicted label: 1.0
# Sample 74800: True label: 1.0, Predicted label: 1.0
# Sample 74880: True label: 1.0, Predicted label: 1.0
# Sample 74960: True label: 0.0, Predicted label: 1.0
# Sample 75040: True label: 1.0, Predicted label: 1.0
# Sample 75120: True label: 1.0, Predicted label: 1.0
# Sample 75200: True label: 1.0, Predicted label: 1.0
# Sample 75280: True label: 1.0, Predicted label: 1.0
# Sample 75360: True label: 1.0, Predicted label: 1.0
# Sample 75440: True label: 1.0, Predicted label: 1.0
# Sample 75520: True label: 1.0, Predicted label: 1.0
# Sample 75600: True label: 1.0, Predicted label: 1.0
# Sample 75680: True label: 1.0, Predicted label: 1.0
# Sample 75760: True label: 1.0, Predicted label: 1.0
# Sample 75840: True label: 1.0, Predicted label: 1.0
# Sample 75920: True label: 1.0, Predicted label: 1.0
# Sample 76000: True label: 0.0, Predicted label: 0.0
# Sample 76080: True label: 1.0, Predicted label: 1.0
# Sample 76160: True label: 0.0, Predicted label: 0.0
# Sample 76240: True label: 1.0, Predicted label: 1.0
# Sample 76320: True label: 1.0, Predicted label: 1.0
# Sample 76400: True label: 1.0, Predicted label: 1.0
# Sample 76480: True label: 1.0, Predicted label: 1.0
# Sample 76560: True label: 1.0, Predicted label: 1.0
# Sample 76640: True label: 1.0, Predicted label: 1.0
# Sample 76720: True label: 1.0, Predicted label: 1.0
# Sample 76800: True label: 0.0, Predicted label: 0.0
# Sample 76880: True label: 1.0, Predicted label: 1.0
# Sample 76960: True label: 1.0, Predicted label: 1.0
# Sample 77040: True label: 1.0, Predicted label: 1.0
# Sample 77120: True label: 0.0, Predicted label: 0.0
# Sample 77200: True label: 1.0, Predicted label: 1.0
# Sample 77280: True label: 1.0, Predicted label: 1.0
# Sample 77360: True label: 1.0, Predicted label: 1.0
# Sample 77440: True label: 1.0, Predicted label: 1.0
# Sample 77520: True label: 1.0, Predicted label: 1.0
# Sample 77600: True label: 1.0, Predicted label: 1.0
# Sample 77680: True label: 1.0, Predicted label: 1.0
# Sample 77760: True label: 1.0, Predicted label: 1.0
# Sample 77840: True label: 0.0, Predicted label: 0.0
# Sample 77920: True label: 1.0, Predicted label: 1.0
# Sample 78000: True label: 1.0, Predicted label: 1.0
# Sample 78080: True label: 1.0, Predicted label: 1.0
# Sample 78160: True label: 0.0, Predicted label: 0.0
# Sample 78240: True label: 1.0, Predicted label: 1.0
# Sample 78320: True label: 0.0, Predicted label: 0.0
# Sample 78400: True label: 1.0, Predicted label: 1.0
# Sample 78480: True label: 1.0, Predicted label: 1.0
# Sample 78560: True label: 1.0, Predicted label: 1.0
# Sample 78640: True label: 1.0, Predicted label: 1.0
# Sample 78720: True label: 0.0, Predicted label: 0.0
# Sample 78800: True label: 1.0, Predicted label: 1.0
# Sample 78880: True label: 1.0, Predicted label: 1.0
# Accuracy: 97.72999999999999%
# Precision: 97.59%
# Recall: 99.78%
# F1-score: 98.67%
# CPU times: total: 11min 42s
# Wall time: 13min 18s

# %%
# %%time
# Use the Hoeffding Tree (HT) model
name1 = "HT model"
model1 = tree.HoeffdingTreeClassifier()  # Define the model
logger1 = setup_logger("hoeffding_drift_detection.log")  # Set up logger for drift detection
t1, m1, logger1 = adaptive_learning(model1, X_train, y_train, X_test, y_test, logger=logger1)  # Learn the model on the dataset
acc_fig(t1, m1, name1)  # Draw the figure of how the real-time accuracy changes with the number of samples

# %%
# %%time
# Use the Extremely Fast Decision Tree (EFDT) model
name3 = "EFDT model"
model3 = tree.ExtremelyFastDecisionTreeClassifier()  # Define the model
logger3 = setup_logger("efdt_drift_detection.log")  # Set up logger for drift detection
t3, m3, logger3 = adaptive_learning(model3, X_train, y_train, X_test, y_test, logger=logger3)  # Learn the model on the dataset
acc_fig(t3, m3, name3)  # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# Accuracy: 83.91999999999999%
# Precision: 83.94%
# Recall: 83.91999999999999%
# F1-score: 83.93%
# CPU times: total: 6min 8s
# Wall time: 6min 34s

# %%
# %%time
# Use the AMF-EDDM model
name4 = "AMF-EDDM model"
model4 = forest.AMFClassifier()  # Define the model
logger4 = setup_logger("amf_eddm_drift_detection.log")  # Set up logger for drift detection
t4, m4, logger4 = adaptive_learning(model4, X_train, y_train, X_test, y_test, logger=logger4)  # Learn the model on the dataset
acc_fig(t4, m4, name4)  # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# Accuracy: 91.69%
# Precision: 91.8%
# Recall: 91.69%
# F1-score: 91.67%
# CPU times: total: 7min 49s
# Wall time: 8min 19s

# %%
# %%time
# Use the SRP Model
name5 = "SRP Model"
model5 = ensemble.SRPClassifier()  # Define the model
logger5 = setup_logger("srp_drift_detection.log")  # Set up logger for drift detection
t5, m5, logger5 = adaptive_learning(model5, X_train, y_train, X_test, y_test, logger=logger5)  # Learn the model on the dataset
acc_fig(t5, m5, name5)  # Draw the figure of how the real-time accuracy changes with the number of samples
# Out:
# Accuracy: 94.54%
# Precision: 94.54%
# Recall: 94.54%
# F1-score: 94.54%
# CPU times: total: 15min 54s
# Wall time: 16min 33s

# %%
start = time.time()

# Use the Voting Classifier model
name10 = "Voting Model"
model10 = ensemble.VotingClassifier(
    [
        ensemble.SRPClassifier(),
        forest.AMFClassifier(),
        forest.ARFClassifier(),
        tree.ExtremelyFastDecisionTreeClassifier(),
        tree.HoeffdingAdaptiveTreeClassifier(),
        tree.HoeffdingTreeClassifier()
    ]
)

# Set up logger for drift detection
logger10 = setup_logger("voting_model_drift_detection.log")

# Learn the model on the dataset
t10, m10, logger10 = adaptive_learning(model10, X_train, y_train, X_test, y_test, logger=logger10)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t10, m10, name10)

end = time.time()
print("Time in seconds:", (end - start))
# Out:
# Accuracy: 91.35%
# Precision: 91.35%
# Recall: 91.35%
# F1-score: 91.35%
# Time in seconds: 2665.4805483818054

# %%
from river import preprocessing

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.ExtremelyFastDecisionTreeClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.HoeffdingAdaptiveTreeClassifier()
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.HoeffdingTreeClassifier()
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.ARFClassifier()
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.AMFClassifier()
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the Leveraging Bagging (LB) model
name6 = "LB model"
model6 = ensemble.LeveragingBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.SRPClassifier()
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger6 = setup_logger("lb_model_drift_detection.log")

# Learn the model on the dataset
t6, m6, logger6 = adaptive_learning(model6, X_train, y_train, X_test, y_test, logger=logger6)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t6, m6, name6)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name7 = "Adwinbagging model"
model7 = ensemble.ADWINBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.HoeffdingAdaptiveTreeClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger7 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t7, m7, logger7 = adaptive_learning(model7, X_train, y_train, X_test, y_test, logger=logger7)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t7, m7, name7)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name7 = "Adwinbagging model"
model7 = ensemble.ADWINBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.HoeffdingTreeClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger7 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t7, m7, logger7 = adaptive_learning(model7, X_train, y_train, X_test, y_test, logger=logger7)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t7, m7, name7)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name7 = "Adwinbagging model"
model7 = ensemble.ADWINBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.ARFClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger7 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t7, m7, logger7 = adaptive_learning(model7, X_train, y_train, X_test, y_test, logger=logger7)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t7, m7, name7)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name7 = "Adwinbagging model"
model7 = ensemble.ADWINBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.AMFClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger7 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t7, m7, logger7 = adaptive_learning(model7, X_train, y_train, X_test, y_test, logger=logger7)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t7, m7, name7)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name7 = "Adwinbagging model"
model7 = ensemble.ADWINBaggingClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.SRPClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger7 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t7, m7, logger7 = adaptive_learning(model7, X_train, y_train, X_test, y_test, logger=logger7)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t7, m7, name7)

# %%
# %%time
# Use the ADWIN Bagging (Adwinbagging) model
name8 = "AdaBoost model"
model8 = ensemble.AdaBoostClassifier(
    model=(
        preprocessing.StandardScaler() |  # Preprocessing with standard scaling
        tree.SRPClassifier()  # Base model
    ),
    n_models=3,  # Number of models in the ensemble
    seed=42  # Random seed for reproducibility
)

# Set up logger for drift detection
logger9 = setup_logger("adwinbagging_model_drift_detection.log")

# Learn the model on the dataset
t8, m8, logger8 = adaptive_learning(model8, X_train, y_train, X_test, y_test, logger=logger8)

# Draw the figure of how the real-time accuracy changes with the number of samples
acc_fig(t8, m8, name8)
